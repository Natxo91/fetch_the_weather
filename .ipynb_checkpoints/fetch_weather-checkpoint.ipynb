# %%
from requests import get
import json
from pprint import pprint

url = 'https://apex.oracle.com/pls/apex/raspberrypi/weatherstation/getallstations'

stations = get(url).json()['items']

# %%
pprint(stations)
# Out:
# [{'weather_stn_id': 255541,
#   'weather_stn_lat': 52.213842,
#   'weather_stn_long': 0.110421,
#   'weather_stn_name': 'Pi Towers Demo'},
#  {'weather_stn_id': 296861,
#   'weather_stn_lat': 52.346752,
#   'weather_stn_long': 0.333975,
#   'weather_stn_name': 'Home'},
#  {'weather_stn_id': 316321,
#   'weather_stn_lat': 52.32984,
#   'weather_stn_long': 0.337129,
#   'weather_stn_name': 'SVC1'},
#  {'weather_stn_id': 490722,
#   'weather_stn_lat': 52.059168,
#   'weather_stn_long': 1.181303,
#   'weather_stn_name': 'JimStation1'},
#  {'weather_stn_id': 497527,
#   'weather_stn_lat': 57.693646,
#   'weather_stn_long': -4.251687,
#   'weather_stn_name': 'Alness Academy '},
#  {'weather_stn_id': 497974,
#   'weather_stn_lat': 52.064358,
#   'weather_stn_long': 1.153287,
#   'weather_stn_name': 'christchurch'},
#  {'weather_stn_id': 504487,
#   'weather_stn_lat': 48.949147,
#   'weather_stn_long': 3.126924,
#   'weather_stn_name': 'pi-celine-77'},
#  {'weather_stn_id': 505047,
#   'weather_stn_lat': 55.009497,
#   'weather_stn_long': -1.614494,
#   'weather_stn_name': 'ARFS1'},
#  {'weather_stn_id': 505307,
#   'weather_stn_lat': 51.383511,
#   'weather_stn_long': 0.538223,
#   'weather_stn_name': 'Test Brompton Academy'},
#  {'weather_stn_id': 505367,
#   'weather_stn_lat': 55.9453,
#   'weather_stn_long': 4.5646,
#   'weather_stn_name': 'Callum_Inglis'},
#  {'weather_stn_id': 506882,
#   'weather_stn_lat': 37.595485,
#   'weather_stn_long': -2.26851,
#   'weather_stn_name': 'Colegio'},
#  {'weather_stn_id': 507567,
#   'weather_stn_lat': 54.517955,
#   'weather_stn_long': -6.050129,
#   'weather_stn_name': 'Wallace Weather'},
#  {'weather_stn_id': 508259,
#   'weather_stn_lat': 54.728729,
#   'weather_stn_long': 25.232436,
#   'weather_stn_name': 'pirmoji'},
#  {'weather_stn_id': 509867,
#   'weather_stn_lat': 57.693646,
#   'weather_stn_long': -4.251687,
#   'weather_stn_name': 'A2'},
#  {'weather_stn_id': 509944,
#   'weather_stn_lat': 50.079793,
#   'weather_stn_long': 1.995599,
#   'weather_stn_name': 'Ecole Victor Hugo'},
#  {'weather_stn_id': 510325,
#   'weather_stn_lat': 54.641816,
#   'weather_stn_long': -6.744389,
#   'weather_stn_name': 'Cookstown High School'},
#  {'weather_stn_id': 511028,
#   'weather_stn_lat': 52.70294,
#   'weather_stn_long': 5.29839,
#   'weather_stn_name': 'station1'},
#  {'weather_stn_id': 511059,
#   'weather_stn_lat': 53.106468,
#   'weather_stn_long': 6.114299,
#   'weather_stn_name': 'IT Weather Station'},
#  {'weather_stn_id': 511878,
#   'weather_stn_lat': 49.85612,
#   'weather_stn_long': 5.252538,
#   'weather_stn_name': 'Station IND'},
#  {'weather_stn_id': 512202,
#   'weather_stn_lat': 36.52785,
#   'weather_stn_long': 23.04514,
#   'weather_stn_name': 'Neapoli Weather Station'},
#  {'weather_stn_id': 515967,
#   'weather_stn_lat': 47.14057,
#   'weather_stn_long': 10.56558,
#   'weather_stn_name': 'Wetterstation BRG/BORG Landeck'},
#  {'weather_stn_id': 518682,
#   'weather_stn_lat': 32.673656,
#   'weather_stn_long': -17.063309,
#   'weather_stn_name': 'Estação Meteorológica'},
#  {'weather_stn_id': 519781,
#   'weather_stn_lat': 37.031846,
#   'weather_stn_long': -7.839955,
#   'weather_stn_name': 'weather-aeffl'},
#  {'weather_stn_id': 520153,
#   'weather_stn_lat': 55.905778,
#   'weather_stn_long': 23.275667,
#   'weather_stn_name': 'WS-SiauliuSauletekioGimnazija'},
#  {'weather_stn_id': 520546,
#   'weather_stn_lat': 52.282774,
#   'weather_stn_long': -0.646623,
#   'weather_stn_name': 'Lab13Irchester'},
#  {'weather_stn_id': 524920,
#   'weather_stn_lat': 35.034109,
#   'weather_stn_long': 25.930117,
#   'weather_stn_name': 'Koutsouras Weather Station'},
#  {'weather_stn_id': 526297,
#   'weather_stn_lat': 10.739801,
#   'weather_stn_long': 47.237048,
#   'weather_stn_name': 'Bundeshandelsakademie Imst'},
#  {'weather_stn_id': 526407,
#   'weather_stn_lat': 51.534122,
#   'weather_stn_long': -1.065971,
#   'weather_stn_name': 'Langtree'},
#  {'weather_stn_id': 528071,
#   'weather_stn_lat': 51.574658,
#   'weather_stn_long': 0.020523,
#   'weather_stn_name': 'ololweather'},
#  {'weather_stn_id': 529275,
#   'weather_stn_lat': 51.24602,
#   'weather_stn_long': -1.134301,
#   'weather_stn_name': 'Garden'},
#  {'weather_stn_id': 534382,
#   'weather_stn_lat': 47.821407,
#   'weather_stn_long': 13.046863,
#   'weather_stn_name': 'HTL Salzburg Wetterstation'},
#  {'weather_stn_id': 541759,
#   'weather_stn_lat': 45.630937,
#   'weather_stn_long': -9.148652,
#   'weather_stn_name': 'meteocesano'},
#  {'weather_stn_id': 552355,
#   'weather_stn_lat': 41.146,
#   'weather_stn_long': 24.155,
#   'weather_stn_name': '4th_Lyceum_of_Drama WS'},
#  {'weather_stn_id': 553868,
#   'weather_stn_lat': 38.196618,
#   'weather_stn_long': 20.439742,
#   'weather_stn_name': 'Lixouri - Kefalonia'},
#  {'weather_stn_id': 553997,
#   'weather_stn_lat': 47.44209,
#   'weather_stn_long': 15.299633,
#   'weather_stn_name': 'HTL Kapfenberg'},
#  {'weather_stn_id': 562837,
#   'weather_stn_lat': 54.728729,
#   'weather_stn_long': 25.232436,
#   'weather_stn_name': 'Raspberry_Pi'},
#  {'weather_stn_id': 567604,
#   'weather_stn_lat': 48.563759,
#   'weather_stn_long': 13.445813,
#   'weather_stn_name': 'ASG Wetterstation'},
#  {'weather_stn_id': 567712,
#   'weather_stn_lat': 38.196634,
#   'weather_stn_long': 20.439724,
#   'weather_stn_name': 'Lixouri2'},
#  {'weather_stn_id': 582067,
#   'weather_stn_lat': 4.850698,
#   'weather_stn_long': 52.29102,
#   'weather_stn_name': 'startbaan3'},
#  {'weather_stn_id': 586603,
#   'weather_stn_lat': 49.627324,
#   'weather_stn_long': 6.107863,
#   'weather_stn_name': 'LML - Lycée Michel Lucius'},
#  {'weather_stn_id': 586921,
#   'weather_stn_lat': 54.01975,
#   'weather_stn_long': 23.9643,
#   'weather_stn_name': 'Druskininkai'},
#  {'weather_stn_id': 587328,
#   'weather_stn_lat': 57.46,
#   'weather_stn_long': 49.03,
#   'weather_stn_name': 'Weather1'},
#  {'weather_stn_id': 587704,
#   'weather_stn_lat': 50.724344,
#   'weather_stn_long': 15.179845,
#   'weather_stn_name': 'vikyr'},
#  {'weather_stn_id': 591441,
#   'weather_stn_lat': 37.926748,
#   'weather_stn_long': -97.317943,
#   'weather_stn_name': 'One'},
#  {'weather_stn_id': 595131,
#   'weather_stn_lat': 51.083455,
#   'weather_stn_long': 17.015699,
#   'weather_stn_name': 'BISCpi'},
#  {'weather_stn_id': 595229,
#   'weather_stn_lat': 40.29728,
#   'weather_stn_long': -76.873569,
#   'weather_stn_name': 'Weather@Londonderry'},
#  {'weather_stn_id': 635457,
#   'weather_stn_lat': 54.554325,
#   'weather_stn_long': 23.351328,
#   'weather_stn_name': 'MRSPM'},
#  {'weather_stn_id': 638013,
#   'weather_stn_lat': 50.813535,
#   'weather_stn_long': 19.108224,
#   'weather_stn_name': 'IVLO_PL'},
#  {'weather_stn_id': 642724,
#   'weather_stn_lat': 42.76871,
#   'weather_stn_long': 11.10955,
#   'weather_stn_name': 'leopoldo'},
#  {'weather_stn_id': 664202,
#   'weather_stn_lat': 51.576,
#   'weather_stn_long': 6.985,
#   'weather_stn_name': 'RatsGladbeck'},
#  {'weather_stn_id': 667471,
#   'weather_stn_lat': 40.631823,
#   'weather_stn_long': 22.74351,
#   'weather_stn_name': 'Weather Station Lyceum of Chalastra - Greece'},
#  {'weather_stn_id': 667858,
#   'weather_stn_lat': 53.301557,
#   'weather_stn_long': -1.466409,
#   'weather_stn_name': 'DHFS Weather Station'},
#  {'weather_stn_id': 668306,
#   'weather_stn_lat': 51.522803,
#   'weather_stn_long': 0.007889,
#   'weather_stn_name': 'Hammers1'},
#  {'weather_stn_id': 672677,
#   'weather_stn_lat': 52.022593,
#   'weather_stn_long': 0.239215,
#   'weather_stn_name': 'Raspberry Pi'},
#  {'weather_stn_id': 678213,
#   'weather_stn_lat': 51.454043,
#   'weather_stn_long': -0.953976,
#   'weather_stn_name': 'Reading College'},
#  {'weather_stn_id': 714944,
#   'weather_stn_lat': 53.263444,
#   'weather_stn_long': 6.007731,
#   'weather_stn_name': 'De Falom'},
#  {'weather_stn_id': 732871,
#   'weather_stn_lat': 40.032064,
#   'weather_stn_long': -75.174831,
#   'weather_stn_name': 'PSD Weather Station'},
#  {'weather_stn_id': 743191,
#   'weather_stn_lat': 51.436598,
#   'weather_stn_long': -1.088424,
#   'weather_stn_name': 'Weatherstation'},
#  {'weather_stn_id': 746708,
#   'weather_stn_lat': 53.616181,
#   'weather_stn_long': 10.027157,
#   'weather_stn_name': 'Bugenhagenschulen Alsterdorf'},
#  {'weather_stn_id': 748308,
#   'weather_stn_lat': 47.791667,
#   'weather_stn_long': 12.953055,
#   'weather_stn_name': 'NMS Laakirchen'},
#  {'weather_stn_id': 751328,
#   'weather_stn_lat': 37.258796,
#   'weather_stn_long': -8.290331,
#   'weather_stn_name': 'messines'},
#  {'weather_stn_id': 783121,
#   'weather_stn_lat': 39.097639,
#   'weather_stn_long': 26.547785,
#   'weather_stn_name': 'Mytilene, Lesvos, Greece'},
#  {'weather_stn_id': 785419,
#   'weather_stn_lat': 44.14392,
#   'weather_stn_long': 4.76819,
#   'weather_stn_name': 'MeteoMartignan'},
#  {'weather_stn_id': 817901,
#   'weather_stn_lat': 40.61234,
#   'weather_stn_long': 22.966715,
#   'weather_stn_name': 'test20'},
#  {'weather_stn_id': 850196,
#   'weather_stn_lat': 44.763085,
#   'weather_stn_long': -108.741988,
#   'weather_stn_name': 'Powell High School Panther Prognosticator'},
#  {'weather_stn_id': 850212,
#   'weather_stn_lat': 31.406818,
#   'weather_stn_long': 73.120028,
#   'weather_stn_name': 'Beacon House School System'},
#  {'weather_stn_id': 858983,
#   'weather_stn_lat': 51.579585,
#   'weather_stn_long': -0.28202,
#   'weather_stn_name': 'SJPS Weather Station '},
#  {'weather_stn_id': 860212,
#   'weather_stn_lat': -30.058211,
#   'weather_stn_long': -51.173452,
#   'weather_stn_name': 'LTIGWeatherStation'},
#  {'weather_stn_id': 903675,
#   'weather_stn_lat': 60.882073,
#   'weather_stn_long': 11.562468,
#   'weather_stn_name': 'EK-WeatherStation'},
#  {'weather_stn_id': 906364,
#   'weather_stn_lat': 54.315,
#   'weather_stn_long': -130.3208,
#   'weather_stn_name': 'Prince Rupert Weather Station'},
#  {'weather_stn_id': 927079,
#   'weather_stn_lat': -33.439168,
#   'weather_stn_long': -70.657827,
#   'weather_stn_name': 'weather'},
#  {'weather_stn_id': 965816,
#   'weather_stn_lat': 63.401104,
#   'weather_stn_long': 10.430993,
#   'weather_stn_name': 'Steindal Weather'},
#  {'weather_stn_id': 966583,
#   'weather_stn_lat': -28.95078,
#   'weather_stn_long': -49.468256,
#   'weather_stn_name': 'UFSC'},
#  {'weather_stn_id': 970027,
#   'weather_stn_lat': 40.619473,
#   'weather_stn_long': 17.616081,
#   'weather_stn_name': 'test01'},
#  {'weather_stn_id': 989061,
#   'weather_stn_lat': 22.315232,
#   'weather_stn_long': 70.816118,
#   'weather_stn_name': 'Test_Weather'},
#  {'weather_stn_id': 1002485,
#   'weather_stn_lat': 51.074739,
#   'weather_stn_long': -114.070677,
#   'weather_stn_name': 'Ecole de la Rose sauvage, Calgary, Canada'},
#  {'weather_stn_id': 1042161,
#   'weather_stn_lat': 53.380281,
#   'weather_stn_long': -2.118961,
#   'weather_stn_name': 'Test Weather Station'},
#  {'weather_stn_id': 1054592,
#   'weather_stn_lat': 40.292689,
#   'weather_stn_long': 21.789313,
#   'weather_stn_name': 'Aeolus'},
#  {'weather_stn_id': 1058817,
#   'weather_stn_lat': 7.267903,
#   'weather_stn_long': 80.692329,
#   'weather_stn_name': 'Hill City SL'},
#  {'weather_stn_id': 1072679,
#   'weather_stn_lat': 37.2152,
#   'weather_stn_long': 93.2826,
#   'weather_stn_name': 'OTC-NET'},
#  {'weather_stn_id': 1072737,
#   'weather_stn_lat': 35.212923,
#   'weather_stn_long': 26.109291,
#   'weather_stn_name': '3rd_Primary_School_of_Sitia'},
#  {'weather_stn_id': 1073533,
#   'weather_stn_lat': 52.412773,
#   'weather_stn_long': 20.931398,
#   'weather_stn_name': 'Stacja_STO35'},
#  {'weather_stn_id': 1100597,
#   'weather_stn_lat': 35.771804,
#   'weather_stn_long': -78.66629,
#   'weather_stn_name': 'Wake STEM ECHS Weather Station'},
#  {'weather_stn_id': 1101852,
#   'weather_stn_lat': 52.375235,
#   'weather_stn_long': 20.927556,
#   'weather_stn_name': 'Jablonna Szkolna 2'},
#  {'weather_stn_id': 1111673,
#   'weather_stn_lat': 46.198645,
#   'weather_stn_long': 6.172578,
#   'weather_stn_name': 'lgbmsweather'},
#  {'weather_stn_id': 1158690,
#   'weather_stn_lat': 37.727497,
#   'weather_stn_long': -121.869422,
#   'weather_stn_name': 'QLS Aramona Weather Station'},
#  {'weather_stn_id': 1185626,
#   'weather_stn_lat': 48.544859,
#   'weather_stn_long': 2.633721,
#   'weather_stn_name': 'StationElsa'},
#  {'weather_stn_id': 1187110,
#   'weather_stn_lat': 56.122828,
#   'weather_stn_long': 12.301261,
#   'weather_stn_name': 'Gilbjergskolen'},
#  {'weather_stn_id': 1195685,
#   'weather_stn_lat': 14.079444,
#   'weather_stn_long': 100.61196,
#   'weather_stn_name': 'RSWeatherLab'},
#  {'weather_stn_id': 1207198,
#   'weather_stn_lat': 5.71583,
#   'weather_stn_long': 72.92722,
#   'weather_stn_name': 'Test School weather station REYES PATRIA'},
#  {'weather_stn_id': 1211299,
#   'weather_stn_lat': 52.570474,
#   'weather_stn_long': 6.624213,
#   'weather_stn_name': 'Greijdanus-Weather'},
#  {'weather_stn_id': 1212453,
#   'weather_stn_lat': 51.547657,
#   'weather_stn_long': -0.109745,
#   'weather_stn_name': 'St Mary Magdalene Academy'},
#  {'weather_stn_id': 1247443,
#   'weather_stn_lat': 46.622472,
#   'weather_stn_long': 5.211796,
#   'weather_stn_name': 'MeteoPi71'},
#  {'weather_stn_id': 1253673,
#   'weather_stn_lat': 41.722222,
#   'weather_stn_long': -92.349629,
#   'weather_stn_name': 'CHS_Main01'},
#  {'weather_stn_id': 1256821,
#   'weather_stn_lat': -37.973283,
#   'weather_stn_long': 176.976029,
#   'weather_stn_name': 'Trident Weather'},
#  {'weather_stn_id': 1260922,
#   'weather_stn_lat': 8.145496,
#   'weather_stn_long': 5.162386,
#   'weather_stn_name': 'TAICO Digital Weather'},
#  {'weather_stn_id': 1261471,
#   'weather_stn_lat': 52.19513,
#   'weather_stn_long': 0.131768,
#   'weather_stn_name': 'Pi Towers'},
#  {'weather_stn_id': 1269584,
#   'weather_stn_lat': 35.0853,
#   'weather_stn_long': 106.6056,
#   'weather_stn_name': 'Test Central New Mexico College Weather Station'},
#  {'weather_stn_id': 1280720,
#   'weather_stn_lat': 55.947735,
#   'weather_stn_long': -4.551631,
#   'weather_stn_name': 'TheAmazingGinger'},
#  {'weather_stn_id': 1287993,
#   'weather_stn_lat': 52.448646,
#   'weather_stn_long': 1.724796,
#   'weather_stn_name': 'Roofie'},
#  {'weather_stn_id': 1301424,
#   'weather_stn_lat': 40.586258,
#   'weather_stn_long': -98.38987,
#   'weather_stn_name': 'Hastings High School'},
#  {'weather_stn_id': 1307290,
#   'weather_stn_lat': 47.41094,
#   'weather_stn_long': 9.729244,
#   'weather_stn_name': 'BRG/BORG Schoren Dornbirn'},
#  {'weather_stn_id': 1346157,
#   'weather_stn_lat': 1.542145,
#   'weather_stn_long': 110.326207,
#   'weather_stn_name': 'RPI Solar'},
#  {'weather_stn_id': 1355086,
#   'weather_stn_lat': 40.597778,
#   'weather_stn_long': 22.969889,
#   'weather_stn_name': '32GEL_WEATHER_STATION'},
#  {'weather_stn_id': 1356217,
#   'weather_stn_lat': -0.152797,
#   'weather_stn_long': 52.782151,
#   'weather_stn_name': 'AHS-1'},
#  {'weather_stn_id': 1366410,
#   'weather_stn_lat': 40.377537,
#   'weather_stn_long': -80.045021,
#   'weather_stn_name': 'IBTeam'},
#  {'weather_stn_id': 1373810,
#   'weather_stn_lat': 53.906402,
#   'weather_stn_long': -1.749303,
#   'weather_stn_name': 'bweather'},
#  {'weather_stn_id': 1406723,
#   'weather_stn_lat': -26.10088,
#   'weather_stn_long': 28.19728,
#   'weather_stn_name': 'ZS6SSG_WS'},
#  {'weather_stn_id': 1432008,
#   'weather_stn_lat': 40.667224,
#   'weather_stn_long': 22.900797,
#   'weather_stn_name': 'Weather St Thess EPAL  Kordeliou'},
#  {'weather_stn_id': 1483831,
#   'weather_stn_lat': 37.388557,
#   'weather_stn_long': 126.995946,
#   'weather_stn_name': 'DeokJang Middle School Weather station'},
#  {'weather_stn_id': 1519124,
#   'weather_stn_lat': -32.55,
#   'weather_stn_long': 115.7,
#   'weather_stn_name': 'Frederick Irwin Anglican School Weather Station 01'},
#  {'weather_stn_id': 1546872,
#   'weather_stn_lat': 58.45468,
#   'weather_stn_long': -78.10139,
#   'weather_stn_name': 'ColdWeatherOrNot'},
#  {'weather_stn_id': 1551853,
#   'weather_stn_lat': 48.9897,
#   'weather_stn_long': 2.819181,
#   'weather_stn_name': 'test school weather station'},
#  {'weather_stn_id': 1569432,
#   'weather_stn_lat': 38.280918,
#   'weather_stn_long': 21.790813,
#   'weather_stn_name': 'pgppRPWS'},
#  {'weather_stn_id': 1569473,
#   'weather_stn_lat': 39.566543,
#   'weather_stn_long': 21.771845,
#   'weather_stn_name': '7thHSWeatherStation'},
#  {'weather_stn_id': 1572018,
#   'weather_stn_lat': -20.672725,
#   'weather_stn_long': -46.262987,
#   'weather_stn_name': 'rancho'},
#  {'weather_stn_id': 1589231,
#   'weather_stn_lat': 48.9897,
#   'weather_stn_long': 2.819181,
#   'weather_stn_name': 'coba'},
#  {'weather_stn_id': 1591042,
#   'weather_stn_lat': 52.190844,
#   'weather_stn_long': 0.163486,
#   'weather_stn_name': 'CB1_3TD'},
#  {'weather_stn_id': 1592317,
#   'weather_stn_lat': 46.815696,
#   'weather_stn_long': -71.316568,
#   'weather_stn_name': 'Station météo La Camaradière'},
#  {'weather_stn_id': 1598227,
#   'weather_stn_lat': 39.563132,
#   'weather_stn_long': 21.776344,
#   'weather_stn_name': '1ekTrikalon'},
#  {'weather_stn_id': 1604642,
#   'weather_stn_lat': 40.238936,
#   'weather_stn_long': 23.290841,
#   'weather_stn_name': 'GENERAL LYCEUM OF NEA MOUDANIA'},
#  {'weather_stn_id': 1615966,
#   'weather_stn_lat': -35.140833,
#   'weather_stn_long': 138.492331,
#   'weather_stn_name': 'Cardijn'},
#  {'weather_stn_id': 1621459,
#   'weather_stn_lat': 54.125221,
#   'weather_stn_long': -2.761019,
#   'weather_stn_name': 'Main'},
#  {'weather_stn_id': 1624210,
#   'weather_stn_lat': 37.568611,
#   'weather_stn_long': -84.296389,
#   'weather_stn_name': 'BCWeather'},
#  {'weather_stn_id': 1648902,
#   'weather_stn_lat': 52.197834,
#   'weather_stn_long': 0.125366,
#   'weather_stn_name': 'ACRG_ROOF'},
#  {'weather_stn_id': 1672266,
#   'weather_stn_lat': 33.578219,
#   'weather_stn_long': -101.860862,
#   'weather_stn_name': 'LHSWest'},
#  {'weather_stn_id': 1672572,
#   'weather_stn_lat': 51.14931,
#   'weather_stn_long': 0.87808,
#   'weather_stn_name': 'Ashford'},
#  {'weather_stn_id': 1674106,
#   'weather_stn_lat': 39.372212,
#   'weather_stn_long': -104.85609,
#   'weather_stn_name': 'CRMSWeatherStation'},
#  {'weather_stn_id': 1682287,
#   'weather_stn_lat': 39.873945,
#   'weather_stn_long': 25.274616,
#   'weather_stn_name': 'MeteoMoudros'},
#  {'weather_stn_id': 1683740,
#   'weather_stn_lat': 39.871621,
#   'weather_stn_long': -4.024121,
#   'weather_stn_name': 'ieselgreco weather station'},
#  {'weather_stn_id': 1684223,
#   'weather_stn_lat': 35.1465,
#   'weather_stn_long': -106.8921,
#   'weather_stn_name': 'Smart Lab WS'},
#  {'weather_stn_id': 1685180,
#   'weather_stn_lat': 31.251947,
#   'weather_stn_long': -93.982168,
#   'weather_stn_name': 'West Sabine'},
#  {'weather_stn_id': 1704961,
#   'weather_stn_lat': 40.658055,
#   'weather_stn_long': 22.921949,
#   'weather_stn_name': 'Ampelokhpoi Weather Station'},
#  {'weather_stn_id': 1724573,
#   'weather_stn_lat': 46.815696,
#   'weather_stn_long': -71.316568,
#   'weather_stn_name': 'CamaWeather'},
#  {'weather_stn_id': 1737372,
#   'weather_stn_lat': 22.396428,
#   'weather_stn_long': 114.109497,
#   'weather_stn_name': 'DBS Weather Station'},
#  {'weather_stn_id': 1764846,
#   'weather_stn_lat': 43.46992,
#   'weather_stn_long': -3.809037,
#   'weather_stn_name': 'DGB'},
#  {'weather_stn_id': 1798309,
#   'weather_stn_lat': 43.646725,
#   'weather_stn_long': -116.282671,
#   'weather_stn_name': 'Discovery Elementary'},
#  {'weather_stn_id': 1803944,
#   'weather_stn_lat': 53.275787,
#   'weather_stn_long': -6.382476,
#   'weather_stn_name': 'scheart'},
#  {'weather_stn_id': 1806483,
#   'weather_stn_lat': -41.19,
#   'weather_stn_long': 174.94,
#   'weather_stn_name': 'Naenae College'},
#  {'weather_stn_id': 1806941,
#   'weather_stn_lat': -90,
#   'weather_stn_long': -180,
#   'weather_stn_name': 'CollegeKarr'},
#  {'weather_stn_id': 1826435,
#   'weather_stn_lat': 45.526646,
#   'weather_stn_long': -122.693621,
#   'weather_stn_name': 'metropolitan learning center'},
#  {'weather_stn_id': 1853105,
#   'weather_stn_lat': 43.4483,
#   'weather_stn_long': 79.78355,
#   'weather_stn_name': 'Crusaders'},
#  {'weather_stn_id': 1880895,
#   'weather_stn_lat': 36.823041,
#   'weather_stn_long': 21.705036,
#   'weather_stn_name': 'Methoni_station'},
#  {'weather_stn_id': 1881560,
#   'weather_stn_lat': 51.899058,
#   'weather_stn_long': -2.076119,
#   'weather_stn_name': 'Wallace'},
#  {'weather_stn_id': 1889138,
#   'weather_stn_lat': -23.974113,
#   'weather_stn_long': -48.889883,
#   'weather_stn_name': 'estacao_itapeva'},
#  {'weather_stn_id': 1937053,
#   'weather_stn_lat': 36.958631,
#   'weather_stn_long': 26.963872,
#   'weather_stn_name': 'Epal Kalymnou Weather Station'},
#  {'weather_stn_id': 1951160,
#   'weather_stn_lat': 38.114566,
#   'weather_stn_long': 23.769887,
#   'weather_stn_name': 'weather-26dim-01'},
#  {'weather_stn_id': 1997888,
#   'weather_stn_lat': 1.293592,
#   'weather_stn_long': 103.81238,
#   'weather_stn_name': 'QTSS Weather Station'},
#  {'weather_stn_id': 2023852,
#   'weather_stn_lat': 44.449412,
#   'weather_stn_long': -92.266844,
#   'weather_stn_name': 'Lake City Lincoln High School'},
#  {'weather_stn_id': 2024689,
#   'weather_stn_lat': 39.181796,
#   'weather_stn_long': -84.36644,
#   'weather_stn_name': 'SGS Chicken'},
#  {'weather_stn_id': 2059087,
#   'weather_stn_lat': 46.851525,
#   'weather_stn_long': -71.424587,
#   'weather_stn_name': 'SLI-Weather'},
#  {'weather_stn_id': 2174090,
#   'weather_stn_lat': 49.337148,
#   'weather_stn_long': -123.161068,
#   'weather_stn_name': 'WVSSWeather'},
#  {'weather_stn_id': 2199879,
#   'weather_stn_lat': 37.566441,
#   'weather_stn_long': 22.799358,
#   'weather_stn_name': 'Esperino Nafplio Weather Station'},
#  {'weather_stn_id': 2237982,
#   'weather_stn_lat': 52.205,
#   'weather_stn_long': 0.119,
#   'weather_stn_name': 'RaspberryHigh-01'},
#  {'weather_stn_id': 2263715,
#   'weather_stn_lat': 54.733041,
#   'weather_stn_long': 25.229961,
#   'weather_stn_name': 'Gabijos gimnazija'},
#  {'weather_stn_id': 2278828,
#   'weather_stn_lat': 38.598677,
#   'weather_stn_long': -9.096835,
#   'weather_stn_name': 'Colegio Atlantico'},
#  {'weather_stn_id': 2279628,
#   'weather_stn_lat': 40.405667,
#   'weather_stn_long': -3.703272,
#   'weather_stn_name': 'Cervantes_Madrid'},
#  {'weather_stn_id': 2287271,
#   'weather_stn_lat': 49.3479,
#   'weather_stn_long': -123.184529,
#   'weather_stn_name': 'Collingwood School'},
#  {'weather_stn_id': 2328257,
#   'weather_stn_lat': 18.712247,
#   'weather_stn_long': 98.999583,
#   'weather_stn_name': 'CDSC1'},
#  {'weather_stn_id': 2328632,
#   'weather_stn_lat': 51.459813,
#   'weather_stn_long': -0.939262,
#   'weather_stn_name': 'Reading TVP'},
#  {'weather_stn_id': 2330964,
#   'weather_stn_lat': 51.459759,
#   'weather_stn_long': -0.939627,
#   'weather_stn_name': 'OracleHQ'},
#  {'weather_stn_id': 2331231,
#   'weather_stn_lat': 51.459759,
#   'weather_stn_long': -0.939627,
#   'weather_stn_name': 'OracleTVP'},
#  {'weather_stn_id': 2336391,
#   'weather_stn_lat': 35.312219,
#   'weather_stn_long': 25.13685,
#   'weather_stn_name': '5gym-meteo'},
#  {'weather_stn_id': 2336406,
#   'weather_stn_lat': 60.516397,
#   'weather_stn_long': 10.295881,
#   'weather_stn_name': 'Awesome TIP Bjoneroa U-trinn 2016/17'},
#  {'weather_stn_id': 2339048,
#   'weather_stn_lat': 48.13197,
#   'weather_stn_long': -101.243404,
#   'weather_stn_name': 'Roll Magi'},
#  {'weather_stn_id': 2339720,
#   'weather_stn_lat': 28.48,
#   'weather_stn_long': -16.31,
#   'weather_stn_name': 'La Salle La Laguna'},
#  {'weather_stn_id': 2340156,
#   'weather_stn_lat': 42.006509,
#   'weather_stn_long': -91.67233,
#   'weather_stn_name': 'Isaac Newton Weather Station'},
#  {'weather_stn_id': 2340898,
#   'weather_stn_lat': 41.090923,
#   'weather_stn_long': 23.54132,
#   'weather_stn_name': 'eolos2'},
#  {'weather_stn_id': 2341664,
#   'weather_stn_lat': 4.629829,
#   'weather_stn_long': -74.148614,
#   'weather_stn_name': 'WeatherStation FTRV'},
#  {'weather_stn_id': 2385124,
#   'weather_stn_lat': 52.361764,
#   'weather_stn_long': 4.91853,
#   'weather_stn_name': 'Raspberry - Coderclass'},
#  {'weather_stn_id': 2385207,
#   'weather_stn_lat': 53.606139,
#   'weather_stn_long': 9.467783,
#   'weather_stn_name': 'VLG-Stade-Pi'},
#  {'weather_stn_id': 2386324,
#   'weather_stn_lat': 44.500794,
#   'weather_stn_long': 10.942769,
#   'weather_stn_name': 'ICC (Italy)'},
#  {'weather_stn_id': 2387750,
#   'weather_stn_lat': 25.78,
#   'weather_stn_long': 77.22,
#   'weather_stn_name': 'MWD in India'},
#  {'weather_stn_id': 2394129,
#   'weather_stn_lat': 48.098884,
#   'weather_stn_long': 16.270373,
#   'weather_stn_name': 'BRGMERaspi'},
#  {'weather_stn_id': 2395299,
#   'weather_stn_lat': 42.437589,
#   'weather_stn_long': -8.869725,
#   'weather_stn_name': 'meteonoalla'},
#  {'weather_stn_id': 2398380,
#   'weather_stn_lat': 29.729853,
#   'weather_stn_long': -93.897354,
#   'weather_stn_name': 'Sabine Pass Weather Station'},
#  {'weather_stn_id': 2416048,
#   'weather_stn_lat': 40.281758,
#   'weather_stn_long': -80.082002,
#   'weather_stn_name': 'PTMS Weather Station'},
#  {'weather_stn_id': 2463152,
#   'weather_stn_lat': 52.55202,
#   'weather_stn_long': 4.686597,
#   'weather_stn_name': 'jpthijsse'},
#  {'weather_stn_id': 2512723,
#   'weather_stn_lat': 32.76608,
#   'weather_stn_long': -17.215484,
#   'weather_stn_name': 'weather station'},
#  {'weather_stn_id': 2514528,
#   'weather_stn_lat': 37.994098,
#   'weather_stn_long': 23.690611,
#   'weather_stn_name': 'temp'},
#  {'weather_stn_id': 2587458,
#   'weather_stn_lat': 29.003875,
#   'weather_stn_long': -80.929284,
#   'weather_stn_name': 'Cuda Weather'},
#  {'weather_stn_id': 2595667,
#   'weather_stn_lat': 50.010064,
#   'weather_stn_long': 14.443388,
#   'weather_stn_name': 'Prage British School'},
#  {'weather_stn_id': 2597299,
#   'weather_stn_lat': 37.970548,
#   'weather_stn_long': 23.694588,
#   'weather_stn_name': 'Zephyrus'},
#  {'weather_stn_id': 2598096,
#   'weather_stn_lat': 42.649077,
#   'weather_stn_long': 23.336631,
#   'weather_stn_name': 'svetlina'},
#  {'weather_stn_id': 2599682,
#   'weather_stn_lat': 11.018678,
#   'weather_stn_long': -74.847151,
#   'weather_stn_name': 'EstacionUninorte'},
#  {'weather_stn_id': 2606192,
#   'weather_stn_lat': 54.55586,
#   'weather_stn_long': 23.349305,
#   'weather_stn_name': 'RaspberryRimanto'},
#  {'weather_stn_id': 2620751,
#   'weather_stn_lat': 35.768448,
#   'weather_stn_long': -78.787274,
#   'weather_stn_name': 'Briarcliff Elmentary'},
#  {'weather_stn_id': 2621163,
#   'weather_stn_lat': 35.76844,
#   'weather_stn_long': -78.787274,
#   'weather_stn_name': 'Briarcliff'},
#  {'weather_stn_id': 2629974,
#   'weather_stn_lat': 40.595883,
#   'weather_stn_long': 22.974998,
#   'weather_stn_name': '2gymchar'},
#  {'weather_stn_id': 2641323,
#   'weather_stn_lat': 37.979,
#   'weather_stn_long': -1.118,
#   'weather_stn_name': 'Tiempecico'},
#  {'weather_stn_id': 2656398,
#   'weather_stn_lat': 35.897517,
#   'weather_stn_long': 14.47975,
#   'weather_stn_name': 'SMCMalta'},
#  {'weather_stn_id': 2667580,
#   'weather_stn_lat': 27.24,
#   'weather_stn_long': 153.1,
#   'weather_stn_name': 'Interalia'},
#  {'weather_stn_id': 2684013,
#   'weather_stn_lat': 38.607484,
#   'weather_stn_long': 21.412311,
#   'weather_stn_name': 'wspi'},
#  {'weather_stn_id': 2686498,
#   'weather_stn_lat': 39.986605,
#   'weather_stn_long': -0.029553,
#   'weather_stn_name': 'WeatherPenyagolosa'},
#  {'weather_stn_id': 2696567,
#   'weather_stn_lat': 40.68125,
#   'weather_stn_long': -75.724205,
#   'weather_stn_name': 'NWL RasPi Weather Station'},
#  {'weather_stn_id': 2705698,
#   'weather_stn_lat': 40.655077,
#   'weather_stn_long': 22.995375,
#   'weather_stn_name': 'DeLaSalleMeteo'},
#  {'weather_stn_id': 2742797,
#   'weather_stn_lat': 42.193862,
#   'weather_stn_long': -88.361212,
#   'weather_stn_name': 'Glacier Ridge'},
#  {'weather_stn_id': 2761266,
#   'weather_stn_lat': 51.272247,
#   'weather_stn_long': -114.016668,
#   'weather_stn_name': 'St. Martin'},
#  {'weather_stn_id': 2784383,
#   'weather_stn_lat': 31.533265,
#   'weather_stn_long': -94.101242,
#   'weather_stn_name': 'San Augustine ISD'},
#  {'weather_stn_id': 2801460,
#   'weather_stn_lat': 39.449652,
#   'weather_stn_long': -75.692097,
#   'weather_stn_name': 'Middletown HS Weather Station'},
#  {'weather_stn_id': 2802581,
#   'weather_stn_lat': 30.4572,
#   'weather_stn_long': 97.8065,
#   'weather_stn_name': 'GRMSWeather'},
#  {'weather_stn_id': 2828199,
#   'weather_stn_lat': 51.503731,
#   'weather_stn_long': 3.900181,
#   'weather_stn_name': 'Maarten-1'},
#  {'weather_stn_id': 2829837,
#   'weather_stn_lat': 47.677861,
#   'weather_stn_long': 13.092652,
#   'weather_stn_name': 'BRGHallein'},
#  {'weather_stn_id': 2833174,
#   'weather_stn_lat': 51.298789,
#   'weather_stn_long': 1.070073,
#   'weather_stn_name': 'CS-UniKent-01'},
#  {'weather_stn_id': 2834106,
#   'weather_stn_lat': 35.24589,
#   'weather_stn_long': 24.41194,
#   'weather_stn_name': 'Panormo Crete'},
#  {'weather_stn_id': 2897247,
#   'weather_stn_lat': 47.354681,
#   'weather_stn_long': 7.912147,
#   'weather_stn_name': 'Kantonsschule Olten'},
#  {'weather_stn_id': 2906985,
#   'weather_stn_lat': 53.73273,
#   'weather_stn_long': 2.76704,
#   'weather_stn_name': 'Hutton Grammar School'},
#  {'weather_stn_id': 2909408,
#   'weather_stn_lat': 43.774612,
#   'weather_stn_long': 11.196697,
#   'weather_stn_name': 'Stazione Meteo Marco Polo'},
#  {'weather_stn_id': 2914063,
#   'weather_stn_lat': 37.834359,
#   'weather_stn_long': 23.795291,
#   'weather_stn_name': 'IRIS_VARI'},
#  {'weather_stn_id': 2969519,
#   'weather_stn_lat': 40.679839,
#   'weather_stn_long': 16.579514,
#   'weather_stn_name': 'WS-IISGBP-MT'},
#  {'weather_stn_id': 2978110,
#   'weather_stn_lat': 38.040429,
#   'weather_stn_long': 23.693743,
#   'weather_stn_name': 'Petroupolis Weather Station'},
#  {'weather_stn_id': 2986433,
#   'weather_stn_lat': 53.9161,
#   'weather_stn_long': 2.9632,
#   'weather_stn_name': 'Saint Aidans CE High School Preesall'},
#  {'weather_stn_id': 2986434,
#   'weather_stn_lat': 53.9161,
#   'weather_stn_long': -2.9632,
#   'weather_stn_name': "Saint Aidan's CE High School Preesall"},
#  {'weather_stn_id': 3002542,
#   'weather_stn_lat': 53.201521,
#   'weather_stn_long': -8.129816,
#   'weather_stn_name': 'Eyrecourt National School'},
#  {'weather_stn_id': 3098532,
#   'weather_stn_lat': 37.364973,
#   'weather_stn_long': -79.281592,
#   'weather_stn_name': 'FMSWX'},
#  {'weather_stn_id': 3105547,
#   'weather_stn_lat': 40.7,
#   'weather_stn_long': -3.933,
#   'weather_stn_name': 'Montesclaros'},
#  {'weather_stn_id': 3113753,
#   'weather_stn_lat': 50.773295,
#   'weather_stn_long': 15.072168,
#   'weather_stn_name': 'TUL1'},
#  {'weather_stn_id': 3157726,
#   'weather_stn_lat': 37.02589,
#   'weather_stn_long': 22.10458,
#   'weather_stn_name': 'Kalamata_tests'},
#  {'weather_stn_id': 3189784,
#   'weather_stn_lat': 53.26366,
#   'weather_stn_long': 7.92705,
#   'weather_stn_name': 'Robert-Dannemann Schule Westerstede'},
#  {'weather_stn_id': 3218645,
#   'weather_stn_lat': -26.772477,
#   'weather_stn_long': 153.117912,
#   'weather_stn_name': 'Talara Primary College'},
#  {'weather_stn_id': 3221048,
#   'weather_stn_lat': 40.671549,
#   'weather_stn_long': 22.912744,
#   'weather_stn_name': 'Diapolitismiko'},
#  {'weather_stn_id': 3231642,
#   'weather_stn_lat': 37.870678,
#   'weather_stn_long': 23.826824,
#   'weather_stn_name': 'Applied_Meteo_Measurements'},
#  {'weather_stn_id': 3231658,
#   'weather_stn_lat': 37.872082,
#   'weather_stn_long': 23.825658,
#   'weather_stn_name': 'GeitonasMeteo'},
#  {'weather_stn_id': 3232969,
#   'weather_stn_lat': 28.130489,
#   'weather_stn_long': -15.439377,
#   'weather_stn_name': 'IES Mesa y Lopez'},
#  {'weather_stn_id': 3238756,
#   'weather_stn_lat': 40.755596,
#   'weather_stn_long': -111.865239,
#   'weather_stn_name': 'Rowland Hall'},
#  {'weather_stn_id': 3238772,
#   'weather_stn_lat': 37.69614,
#   'weather_stn_long': -77.890299,
#   'weather_stn_name': 'Goochland Elementary School'},
#  {'weather_stn_id': 3302727,
#   'weather_stn_lat': 40.751605,
#   'weather_stn_long': -111.862931,
#   'weather_stn_name': 'Rowland Hall Station'},
#  {'weather_stn_id': 3337121,
#   'weather_stn_lat': 47.125393,
#   'weather_stn_long': 10.513063,
#   'weather_stn_name': 'Tobadill Wetter'},
#  {'weather_stn_id': 3338470,
#   'weather_stn_lat': 55.895506,
#   'weather_stn_long': 21.24547,
#   'weather_stn_name': 'Kretinga Vilniaus g. 12'},
#  {'weather_stn_id': 3411235,
#   'weather_stn_lat': 39.624921,
#   'weather_stn_long': 22.417742,
#   'weather_stn_name': 'Anthoupoli Larissa Weather Station'},
#  {'weather_stn_id': 3468211,
#   'weather_stn_lat': 30.437832,
#   'weather_stn_long': -88.80033,
#   'weather_stn_name': 'Jacket Weather'},
#  {'weather_stn_id': 3500251,
#   'weather_stn_lat': 41.619282,
#   'weather_stn_long': -87.047304,
#   'weather_stn_name': 'Indiana Irish Weather'},
#  {'weather_stn_id': 3517233,
#   'weather_stn_lat': -34.8739,
#   'weather_stn_long': -56.0776,
#   'weather_stn_name': 'S12 towers'},
#  {'weather_stn_id': 3527775,
#   'weather_stn_lat': 59.446,
#   'weather_stn_long': 7.986,
#   'weather_stn_name': 'Tokke-01'},
#  {'weather_stn_id': 3527833,
#   'weather_stn_lat': 59.552604,
#   'weather_stn_long': 10.434584,
#   'weather_stn_name': 'christianpower'},
#  {'weather_stn_id': 3528546,
#   'weather_stn_lat': 48.35733,
#   'weather_stn_long': -96.332773,
#   'weather_stn_name': 'MCC Weather Station'},
#  {'weather_stn_id': 3560092,
#   'weather_stn_lat': -56.0776,
#   'weather_stn_long': -34.8739,
#   'weather_stn_name': 'S12_towers'},
#  {'weather_stn_id': 3701748,
#   'weather_stn_lat': 51.379245,
#   'weather_stn_long': -0.391943,
#   'weather_stn_name': 'Test_One'},
#  {'weather_stn_id': 3710868,
#   'weather_stn_lat': -22.3296,
#   'weather_stn_long': -49.073997,
#   'weather_stn_name': 'Fatec Bauru'},
#  {'weather_stn_id': 3721467,
#   'weather_stn_lat': 22.368386,
#   'weather_stn_long': 70.797492,
#   'weather_stn_name': 'Linquestus_wth_stn'},
#  {'weather_stn_id': 3723694,
#   'weather_stn_lat': 53.094706,
#   'weather_stn_long': 8.877415,
#   'weather_stn_name': 'Wetterstation Ronzelenstraße'},
#  {'weather_stn_id': 3725424,
#   'weather_stn_lat': 53.094728,
#   'weather_stn_long': 8.877459,
#   'weather_stn_name': 'Ronzwetter'},
#  {'weather_stn_id': 3740150,
#   'weather_stn_lat': 44.934074,
#   'weather_stn_long': -91.410506,
#   'weather_stn_name': 'Chippewa Falls Dorais Field'},
#  {'weather_stn_id': 3749148,
#   'weather_stn_lat': 52.584392,
#   'weather_stn_long': -0.221165,
#   'weather_stn_name': 'COPA Weather World'},
#  {'weather_stn_id': 3761870,
#   'weather_stn_lat': 44.597686,
#   'weather_stn_long': 11.046687,
#   'weather_stn_name': 'ScuoleGuglielmoMarconi '},
#  {'weather_stn_id': 3763479,
#   'weather_stn_lat': 51.773602,
#   'weather_stn_long': -1.259178,
#   'weather_stn_name': 'adlucem'},
#  {'weather_stn_id': 3787495,
#   'weather_stn_lat': -33.822123,
#   'weather_stn_long': 138.594915,
#   'weather_stn_name': 'CHSWeather'},
#  {'weather_stn_id': 3802732,
#   'weather_stn_lat': 56.883333,
#   'weather_stn_long': 14.816667,
#   'weather_stn_name': 'ProCivitas'},
#  {'weather_stn_id': 3810956,
#   'weather_stn_lat': 37.943391,
#   'weather_stn_long': 23.658022,
#   'weather_stn_name': 'Ralleia'},
#  {'weather_stn_id': 3839752,
#   'weather_stn_lat': 37,
#   'weather_stn_long': 123,
#   'weather_stn_name': 'New Hall'},
#  {'weather_stn_id': 3839753,
#   'weather_stn_lat': 37,
#   'weather_stn_long': 123,
#   'weather_stn_name': 'NewHall'},
#  {'weather_stn_id': 3922671,
#   'weather_stn_lat': 50.110382,
#   'weather_stn_long': 14.341192,
#   'weather_stn_name': 'ISP Weather Station'},
#  {'weather_stn_id': 3943357,
#   'weather_stn_lat': 51.335971,
#   'weather_stn_long': 0.362684,
#   'weather_stn_name': 'Danes Hill School'},
#  {'weather_stn_id': 3945761,
#   'weather_stn_lat': 44.4584,
#   'weather_stn_long': 64.6025,
#   'weather_stn_name': 'wnes-01'},
#  {'weather_stn_id': 3956151,
#   'weather_stn_lat': 54.361131,
#   'weather_stn_long': 24.347201,
#   'weather_stn_name': 'DVM'},
#  {'weather_stn_id': 4034164,
#   'weather_stn_lat': -32.92545,
#   'weather_stn_long': 151.71704,
#   'weather_stn_name': 'Prior Weather Station'},
#  {'weather_stn_id': 4058774,
#   'weather_stn_lat': 21.822976,
#   'weather_stn_long': -102.283683,
#   'weather_stn_name': 'UP Weather Station'},
#  {'weather_stn_id': 4111545,
#   'weather_stn_lat': 52.104131,
#   'weather_stn_long': -106.654687,
#   'weather_stn_name': 'Delisle Elementary'},
#  {'weather_stn_id': 4113163,
#   'weather_stn_lat': 52.06024,
#   'weather_stn_long': 4.34064,
#   'weather_stn_name': 'plusklas'},
#  {'weather_stn_id': 4192584,
#   'weather_stn_lat': 49.462883,
#   'weather_stn_long': 11.085438,
#   'weather_stn_name': 'francesAllen'},
#  {'weather_stn_id': 4206544,
#   'weather_stn_lat': 11.803939,
#   'weather_stn_long': 75.564828,
#   'weather_stn_name': 'MIYmakers'},
#  {'weather_stn_id': 4218356,
#   'weather_stn_lat': 37.128383,
#   'weather_stn_long': -8.422891,
#   'weather_stn_name': 'Nobel International School Weather Station'},
#  {'weather_stn_id': 4230588,
#   'weather_stn_lat': 45.680486,
#   'weather_stn_long': -111.052448,
#   'weather_stn_name': 'Yoda'},
#  {'weather_stn_id': 4260242,
#   'weather_stn_lat': 49.1834,
#   'weather_stn_long': -123.08155,
#   'weather_stn_name': 'WARCS'},
#  {'weather_stn_id': 4283576,
#   'weather_stn_lat': 57.020755,
#   'weather_stn_long': 9.883814,
#   'weather_stn_name': 'UCN'},
#  {'weather_stn_id': 4357095,
#   'weather_stn_lat': -28.100344,
#   'weather_stn_long': 153.430841,
#   'weather_stn_name': 'Marymount College'},
#  {'weather_stn_id': 4498195,
#   'weather_stn_lat': 43.535628,
#   'weather_stn_long': -5.648442,
#   'weather_stn_name': 'codema'},
#  {'weather_stn_id': 4502890,
#   'weather_stn_lat': -26.140485,
#   'weather_stn_long': 28.003471,
#   'weather_stn_name': 'DeWeather'},
#  {'weather_stn_id': 4587424,
#   'weather_stn_lat': 57.141174,
#   'weather_stn_long': -2.431076,
#   'weather_stn_name': 'Echt Weather'},
#  {'weather_stn_id': 4653201,
#   'weather_stn_lat': 52.7641,
#   'weather_stn_long': 1.2015,
#   'weather_stn_name': 'LGS_weather_station'},
#  {'weather_stn_id': 4687780,
#   'weather_stn_lat': 53.814,
#   'weather_stn_long': -1.77,
#   'weather_stn_name': 'BradfordGS-WeatherPi'},
#  {'weather_stn_id': 4699963,
#   'weather_stn_lat': 26.46708,
#   'weather_stn_long': -80.050908,
#   'weather_stn_name': '555'},
#  {'weather_stn_id': 4773739,
#   'weather_stn_lat': -33.762975,
#   'weather_stn_long': 151.281594,
#   'weather_stn_name': 'MSC Weather Station'},
#  {'weather_stn_id': 5021936,
#   'weather_stn_lat': 52.366135,
#   'weather_stn_long': 4.617062,
#   'weather_stn_name': 'LyceumSanctaMaria'},
#  {'weather_stn_id': 5022589,
#   'weather_stn_lat': 52.366135,
#   'weather_stn_long': 4.617062,
#   'weather_stn_name': 'LyceumSanctaMariaWeerstation'},
#  {'weather_stn_id': 5033794,
#   'weather_stn_lat': 7.894878,
#   'weather_stn_long': 98.351759,
#   'weather_stn_name': 'PSU Phuket'},
#  {'weather_stn_id': 5034824,
#   'weather_stn_lat': 32.248524,
#   'weather_stn_long': 145.09302,
#   'weather_stn_name': 'Penbank-Weather01'},
#  {'weather_stn_id': 5206267,
#   'weather_stn_lat': 45.829198,
#   'weather_stn_long': 20.468897,
#   'weather_stn_name': 'Meteorolog Djura'},
#  {'weather_stn_id': 5318644,
#   'weather_stn_lat': 42.28522,
#   'weather_stn_long': -72.658568,
#   'weather_stn_name': 'HCCPS'},
#  {'weather_stn_id': 5318724,
#   'weather_stn_lat': 9.038878,
#   'weather_stn_long': 7.500224,
#   'weather_stn_name': 'Code Ladela'},
#  {'weather_stn_id': 5562385,
#   'weather_stn_lat': 43.610622,
#   'weather_stn_long': -72.972603,
#   'weather_stn_name': 'RACS Rutland, VT'},
#  {'weather_stn_id': 5571586,
#   'weather_stn_lat': 51.631074,
#   'weather_stn_long': -4.913916,
#   'weather_stn_name': 'Penrhyn_weather_station'},
#  {'weather_stn_id': 5577899,
#   'weather_stn_lat': 40.63597,
#   'weather_stn_long': 17.934913,
#   'weather_stn_name': 'test02'},
#  {'weather_stn_id': 5841293,
#   'weather_stn_lat': 9.84,
#   'weather_stn_long': 55.4444,
#   'weather_stn_name': 'Nordvestfyn'},
#  {'weather_stn_id': 5984039,
#   'weather_stn_lat': 37.068617,
#   'weather_stn_long': -8.091795,
#   'weather_stn_name': 'ESLA'},
#  {'weather_stn_id': 5996277,
#   'weather_stn_lat': 30.3009,
#   'weather_stn_long': -99.244214,
#   'weather_stn_name': 'Harper HS Weather Station'},
#  {'weather_stn_id': 6063932,
#   'weather_stn_lat': 52.196595,
#   'weather_stn_long': 0.12037,
#   'weather_stn_name': 'Weather Station'},
#  {'weather_stn_id': 6063961,
#   'weather_stn_lat': 52.196595,
#   'weather_stn_long': 0.12037,
#   'weather_stn_name': 'TheLeys'},
#  {'weather_stn_id': 6107162,
#   'weather_stn_lat': 40.448915,
#   'weather_stn_long': 21.263562,
#   'weather_stn_name': 'GEL Argos Orestiko'},
#  {'weather_stn_id': 6113916,
#   'weather_stn_lat': -21.210075,
#   'weather_stn_long': -47.78587,
#   'weather_stn_name': 'wheather station experiment'},
#  {'weather_stn_id': 6124405,
#   'weather_stn_lat': -21.210075,
#   'weather_stn_long': -47.78587,
#   'weather_stn_name': 'Weather Station Escola de Inventor'},
#  {'weather_stn_id': 6354649,
#   'weather_stn_lat': 52.9546,
#   'weather_stn_long': 0.8489,
#   'weather_stn_name': 'Alderman Peel High School'},
#  {'weather_stn_id': 6366044,
#   'weather_stn_lat': 1.342885,
#   'weather_stn_long': 103.680673,
#   'weather_stn_name': 'WeatherSin1'},
#  {'weather_stn_id': 6844785,
#   'weather_stn_lat': -33.730544,
#   'weather_stn_long': 151.043269,
#   'weather_stn_name': 'Cherrybrook'},
#  {'weather_stn_id': 6938328,
#   'weather_stn_lat': -30.9796,
#   'weather_stn_long': 150.2605,
#   'weather_stn_name': 'SMC-weather-station'},
#  {'weather_stn_id': 6971919,
#   'weather_stn_lat': 32,
#   'weather_stn_long': -16,
#   'weather_stn_name': 'Estacao meteorologica'},
#  {'weather_stn_id': 6987441,
#   'weather_stn_lat': -33.879519,
#   'weather_stn_long': 19.029415,
#   'weather_stn_name': 'Pi Station'},
#  {'weather_stn_id': 6994668,
#   'weather_stn_lat': -10.283683,
#   'weather_stn_long': 21.822976,
#   'weather_stn_name': 'UP Weather'},
#  {'weather_stn_id': 7005356,
#   'weather_stn_lat': 52.109288,
#   'weather_stn_long': 5.024136,
#   'weather_stn_name': 'WeerStationKVS'},
#  {'weather_stn_id': 7019306,
#   'weather_stn_lat': 54.403358,
#   'weather_stn_long': -5.898167,
#   'weather_stn_name': 'AGS Ballynahinch'},
#  {'weather_stn_id': 7089223,
#   'weather_stn_lat': 0,
#   'weather_stn_long': 0,
#   'weather_stn_name': 'MRS'},
#  {'weather_stn_id': 7146209,
#   'weather_stn_lat': 40.423151,
#   'weather_stn_long': 22.934172,
#   'weather_stn_name': 'Epal-Epanomi-1'},
#  {'weather_stn_id': 7152956,
#   'weather_stn_lat': -33.762975,
#   'weather_stn_long': 151.281594,
#   'weather_stn_name': 'MSC Weather Station 1'},
#  {'weather_stn_id': 7234419,
#   'weather_stn_lat': 54.071152,
#   'weather_stn_long': 12.1266,
#   'weather_stn_name': 'Don-Bosco-Wetter'},
#  {'weather_stn_id': 7235690,
#   'weather_stn_lat': 53.08045,
#   'weather_stn_long': -4.020727,
#   'weather_stn_name': 'yhasnowdonpenypass'},
#  {'weather_stn_id': 7260255,
#   'weather_stn_lat': 31.6449,
#   'weather_stn_long': 74.8761,
#   'weather_stn_name': 'dav'},
#  {'weather_stn_id': 7267520,
#   'weather_stn_lat': 38.57985,
#   'weather_stn_long': 23.642865,
#   'weather_stn_name': 'psachna'},
#  {'weather_stn_id': 7300777,
#   'weather_stn_lat': -34.57118,
#   'weather_stn_long': -58.465261,
#   'weather_stn_name': 'emcrpiar'},
#  {'weather_stn_id': 7636225,
#   'weather_stn_lat': 37.058583,
#   'weather_stn_long': 25.40565,
#   'weather_stn_name': 'dimvivlou'},
#  {'weather_stn_id': 7636250,
#   'weather_stn_lat': 25.40565,
#   'weather_stn_long': 37.058583,
#   'weather_stn_name': 'dimvivlou1'},
#  {'weather_stn_id': 7683879,
#   'weather_stn_lat': 59.3507,
#   'weather_stn_long': 2.9004,
#   'weather_stn_name': 'papay school'},
#  {'weather_stn_id': 7722276,
#   'weather_stn_lat': 55.010185,
#   'weather_stn_long': -1.615159,
#   'weather_stn_name': 'GosforthWS'},
#  {'weather_stn_id': 7753960,
#   'weather_stn_lat': 51.361298,
#   'weather_stn_long': 5.469886,
#   'weather_stn_name': 'SgWereDi-01'},
#  {'weather_stn_id': 7860327,
#   'weather_stn_lat': 52.762281,
#   'weather_stn_long': -0.37582,
#   'weather_stn_name': 'BGS Weather Station'},
#  {'weather_stn_id': 7925818,
#   'weather_stn_lat': 45.467881,
#   'weather_stn_long': 9.107272,
#   'weather_stn_name': 'Stazione_Meteo_1'},
#  {'weather_stn_id': 7975980,
#   'weather_stn_lat': 49.624704,
#   'weather_stn_long': 6.113315,
#   'weather_stn_name': 'LML_New'},
#  {'weather_stn_id': 8169140,
#   'weather_stn_lat': 53.415379,
#   'weather_stn_long': -6.474095,
#   'weather_stn_name': 'Dunboyne'},
#  {'weather_stn_id': 8249736,
#   'weather_stn_lat': -28.140688,
#   'weather_stn_long': 153.429815,
#   'weather_stn_name': 'Tallebudgera-01'},
#  {'weather_stn_id': 8284285,
#   'weather_stn_lat': 17.439944,
#   'weather_stn_long': 78.552278,
#   'weather_stn_name': 'DPSHYDTELIN'},
#  {'weather_stn_id': 8477363,
#   'weather_stn_lat': 41.524737,
#   'weather_stn_long': -8.612045,
#   'weather_stn_name': 'Colégio La Salle Barcelos'},
#  {'weather_stn_id': 8495433,
#   'weather_stn_lat': 41.445289,
#   'weather_stn_long': 2.236981,
#   'weather_stn_name': 'SmxStation'},
#  {'weather_stn_id': 8576469,
#   'weather_stn_lat': 53.5898,
#   'weather_stn_long': -2.8511,
#   'weather_stn_name': 'TreeBee2'},
#  {'weather_stn_id': 8673380,
#   'weather_stn_lat': 52.63456,
#   'weather_stn_long': -1.114291,
#   'weather_stn_name': 'Sjncc Weather Station'},
#  {'weather_stn_id': 8809847,
#   'weather_stn_lat': 40.3607,
#   'weather_stn_long': 74.0382,
#   'weather_stn_name': 'Knollwood'},
#  {'weather_stn_id': 8823181,
#   'weather_stn_lat': 41.524634,
#   'weather_stn_long': -8.613281,
#   'weather_stn_name': 'MeteoLasalleBarcelos'},
#  {'weather_stn_id': 9068793,
#   'weather_stn_lat': 35.39,
#   'weather_stn_long': -77.98,
#   'weather_stn_name': 'WSE'},
#  {'weather_stn_id': 9254259,
#   'weather_stn_lat': 40.612114,
#   'weather_stn_long': 22.991911,
#   'weather_stn_name': '10gel1'},
#  {'weather_stn_id': 9276470,
#   'weather_stn_lat': 49.85632,
#   'weather_stn_long': 5.252518,
#   'weather_stn_name': 'Ind Station'},
#  {'weather_stn_id': 9727592,
#   'weather_stn_lat': 54.906778,
#   'weather_stn_long': 9.806403,
#   'weather_stn_name': 'weatherpi'},
#  {'weather_stn_id': 9762816,
#   'weather_stn_lat': 40.611719,
#   'weather_stn_long': 22.980493,
#   'weather_stn_name': '10gel'},
#  {'weather_stn_id': 9821383,
#   'weather_stn_lat': 42.204762,
#   'weather_stn_long': -83.485123,
#   'weather_stn_name': 'RM112WS'},
#  {'weather_stn_id': 10018747,
#   'weather_stn_lat': 48.202755,
#   'weather_stn_long': 16.33912,
#   'weather_stn_name': 'kandlweather'},
#  {'weather_stn_id': 10121743,
#   'weather_stn_lat': 42.589348,
#   'weather_stn_long': -5.565917,
#   'weather_stn_name': 'Trajanita'},
#  {'weather_stn_id': 10535349,
#   'weather_stn_lat': 32.296222,
#   'weather_stn_long': -95.28875,
#   'weather_stn_name': 'CAMSweather'},
#  {'weather_stn_id': 10601637,
#   'weather_stn_lat': 36.9167,
#   'weather_stn_long': 149.8833,
#   'weather_stn_name': 'Pambula'},
#  {'weather_stn_id': 11005431,
#   'weather_stn_lat': 50.978757,
#   'weather_stn_long': -1.374813,
#   'weather_stn_name': 'ToynbeeWeatherStation'},
#  {'weather_stn_id': 11122431,
#   'weather_stn_lat': 37.126,
#   'weather_stn_long': -8.397,
#   'weather_stn_name': 'NobelWS'},
#  {'weather_stn_id': 11374914,
#   'weather_stn_lat': 41.150166,
#   'weather_stn_long': -8.583306,
#   'weather_stn_name': 'EPCJC - Estação meteorológica'},
#  {'weather_stn_id': 11553439,
#   'weather_stn_lat': 52.2,
#   'weather_stn_long': 0.07,
#   'weather_stn_name': 'Cambourne Village College'},
#  {'weather_stn_id': 11597367,
#   'weather_stn_lat': 41.150166,
#   'weather_stn_long': -8.583306,
#   'weather_stn_name': 'epcjc'},
#  {'weather_stn_id': 12034605,
#   'weather_stn_lat': 51.034973,
#   'weather_stn_long': -0.805029,
#   'weather_stn_name': 'BohuntWS'},
#  {'weather_stn_id': 13202079,
#   'weather_stn_lat': -23.182852,
#   'weather_stn_long': -47.276267,
#   'weather_stn_name': 'CYBERCRAFT'},
#  {'weather_stn_id': 13591761,
#   'weather_stn_lat': 38.041204,
#   'weather_stn_long': 23.839146,
#   'weather_stn_name': '2lykvril'},
#  {'weather_stn_id': 13803409,
#   'weather_stn_lat': 54.214617,
#   'weather_stn_long': 24.573597,
#   'weather_stn_name': 'Stotelė'},
#  {'weather_stn_id': 13837689,
#   'weather_stn_lat': 24.5734,
#   'weather_stn_long': 54.2146,
#   'weather_stn_name': 'stotis'},
#  {'weather_stn_id': 15121976,
#   'weather_stn_lat': 40.201742,
#   'weather_stn_long': -8.41295,
#   'weather_stn_name': 'Escola Secundária De Avelar Brotero'},
#  {'weather_stn_id': 15182026,
#   'weather_stn_lat': 55.598279,
#   'weather_stn_long': -2.726814,
#   'weather_stn_name': 'Melrose PS Weather Station'},
#  {'weather_stn_id': 15256426,
#   'weather_stn_lat': 56.82631,
#   'weather_stn_long': 14.936554,
#   'weather_stn_name': 'Katrinelund'},
#  {'weather_stn_id': 15342914,
#   'weather_stn_lat': 37.994107,
#   'weather_stn_long': 23.690533,
#   'weather_stn_name': 'aiolos'},
#  {'weather_stn_id': 15776151,
#   'weather_stn_lat': 5.252538,
#   'weather_stn_long': 49.85612,
#   'weather_stn_name': 'INDBertrix'},
#  {'weather_stn_id': 15948713,
#   'weather_stn_lat': 0.2,
#   'weather_stn_long': -1.5,
#   'weather_stn_name': 'test2'},
#  {'weather_stn_id': 15980819,
#   'weather_stn_lat': 40.976,
#   'weather_stn_long': 22.065,
#   'weather_stn_name': 'Almopos'},
#  {'weather_stn_id': 16360081,
#   'weather_stn_lat': 38.0644,
#   'weather_stn_long': 23.8148,
#   'weather_stn_name': 'anavritaki'},
#  {'weather_stn_id': 16646491,
#   'weather_stn_lat': 48.75701,
#   'weather_stn_long': -122.471776,
#   'weather_stn_name': 'Options High School'},
#  {'weather_stn_id': 17056769,
#   'weather_stn_lat': 54.657297,
#   'weather_stn_long': -5.664445,
#   'weather_stn_name': '4cast'},
#  {'weather_stn_id': 17200273,
#   'weather_stn_lat': 54.65369,
#   'weather_stn_long': -5.67438,
#   'weather_stn_name': 'BASFC'},
#  {'weather_stn_id': 17650487,
#   'weather_stn_lat': 40.644784,
#   'weather_stn_long': 17.926451,
#   'weather_stn_name': 'Liceo Scientifico Statale Fermi - Monticelli'},
#  {'weather_stn_id': 18386842,
#   'weather_stn_lat': 50.839,
#   'weather_stn_long': -0.134,
#   'weather_stn_name': 'downs-junior-01'},
#  {'weather_stn_id': 18544112,
#   'weather_stn_lat': 33.83525,
#   'weather_stn_long': 35.570028,
#   'weather_stn_name': 'Loueizeh Weather'},
#  {'weather_stn_id': 18560234,
#   'weather_stn_lat': 39.375966,
#   'weather_stn_long': 21.908211,
#   'weather_stn_name': '5lyckarditsasWS'},
#  {'weather_stn_id': 19378119,
#   'weather_stn_lat': 53.317,
#   'weather_stn_long': -3.46,
#   'weather_stn_name': 'Raspberry Pi Shed North Wales'},
#  {'weather_stn_id': 19445675,
#   'weather_stn_lat': 40.61,
#   'weather_stn_long': -73.648,
#   'weather_stn_name': 'Madison'},
#  {'weather_stn_id': 19760250,
#   'weather_stn_lat': -20.622725,
#   'weather_stn_long': -46.262987,
#   'weather_stn_name': 'rancho1'},
#  {'weather_stn_id': 19760270,
#   'weather_stn_lat': 52.551776,
#   'weather_stn_long': 4.686843,
#   'weather_stn_name': 'FELAME'},
#  {'weather_stn_id': 19760291,
#   'weather_stn_lat': 57.69447,
#   'weather_stn_long': -4.246387,
#   'weather_stn_name': 'A3'},
#  {'weather_stn_id': 19760310,
#   'weather_stn_lat': 53.317,
#   'weather_stn_long': -3.46,
#   'weather_stn_name': 'The Pi Shed'},
#  {'weather_stn_id': 19760330,
#   'weather_stn_lat': 53.915256,
#   'weather_stn_long': -2.963457,
#   'weather_stn_name': 'A place to call 127.0.0.1'},
#  {'weather_stn_id': 19760350,
#   'weather_stn_lat': 47.93,
#   'weather_stn_long': 16.26,
#   'weather_stn_name': 'Hitz'},
#  {'weather_stn_id': 19760370,
#   'weather_stn_lat': -21.35,
#   'weather_stn_long': -47.66,
#   'weather_stn_name': 'Nova Suíça - Curral'}]

# %%
url = 'https://apex.oracle.com/pls/apex/raspberrypi/weatherstation/getlatestmeasurements/509944'
weather = get(url).json()['items']

# %%
pprint(weather)
# Out:
# [{'air_pressure': 1035.32,
#   'air_quality': 75.29,
#   'ambient_temp': 12.95,
#   'created_by': 'Ecole Victor Hugo',
#   'created_on': '2019-01-07T04:00:02Z',
#   'ground_temp': 5.19,
#   'humidity': 62.42,
#   'id': 16362813,
#   'rainfall': 0,
#   'reading_timestamp': '2019-01-07T04:00:02Z',
#   'updated_by': 'Ecole Victor Hugo',
#   'updated_on': '2019-03-26T11:00:26.554Z',
#   'weather_stn_id': 509944,
#   'wind_direction': 90,
#   'wind_gust_speed': 1.92,
#   'wind_speed': 0.41}]
